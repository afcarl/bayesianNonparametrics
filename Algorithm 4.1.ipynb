# %%
using Distributions
using Plots
gr()
# Out:
# Plots.GRBackend()

# %%
normal = Normal()
# Out:
# Distributions.Normal{Float64}(μ=0.0, σ=1.0)

# %%
mu = 0.7
sigma = 0.5
a = mu + sigma*rand(normal, 100, 2);

# %%
mu = -mu
sigma = 0.4
b = mu + sigma*rand(normal, 100, 2);

# %%
scatter(a[:, 1], a[:, 2], label="class 1")
scatter!(b[:, 1], b[:, 2], label="class 2")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9600)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9600)" points="
# 39.1436,375.813 580.315,375.813 580.315,11.811 39.1436,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="11" width="542" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip9602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   127.791,370.353 127.791,17.2711
#   "/>
# ...

# %%
K = 2
data = [a; b]
num_sample, dim = size(data)
# Out:
# (200, 2)

# %%
z = rand(1:K, num_sample);

# %%
function get_mu(K, data, z)
    mu_list = zeros(K, dim)

    for c in 1:K
        indices = find(z .== c)
        mu_list[c, :] = mean(data[indices, :], 1)
    end
    return mu_list
end
# Out:
# get_mu (generic function with 1 method)

# %%
mu_list = get_mu(K, data, z)
for _ in 1:200
    for i in 1:num_sample
        x = data[i, :]
        z[i] = indmin([vecdot(x - mu_list[c, :], x - mu_list[c, :]) for c in 1:K])# indmax
    end
    mu_list = get_mu(K, data, z) 
end

# %%
c = 1
indices = find(z .== c)
scatter(data[indices, 1], data[indices, 2], label="z=1")

c = 2
indices = find(z .== c)
scatter!(data[indices, 1], data[indices, 2], label="z=2")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9800)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9800)" points="
# 39.1436,375.813 580.315,375.813 580.315,11.811 39.1436,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="11" width="542" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip9802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   127.791,370.353 127.791,17.2711
#   "/>
# ...
